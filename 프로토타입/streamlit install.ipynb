# %%
pip install streamlit-nested-layout
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for streamlit-nested-layout: filename=streamlit_nested_layout-0.1.1-py3-none-any.whl size=7076 sha256=27f54efea100ac0460cb83bbb92b70e41b1699edd0ed01168a64ed0214f73846
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\64\99\94\b4508b79b73f012b4996e12528e949fe3fab4bfd68b0f2fd24
# Successfully built streamlit-nested-layout
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# ...
#                                               0.0/1.1 MB ? eta -:--:--
#      -------                                  0.2/1.1 MB 3.9 MB/s eta 0:00:01
#      -----------------                        0.5/1.1 MB 6.0 MB/s eta 0:00:01
#      --------------------------               0.7/1.1 MB 5.7 MB/s eta 0:00:01
#      ----------------------------------       1.0/1.1 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 5.4 MB/s eta 0:00:00
# ...
#                                               0.0/22.9 MB ? eta -:--:--
#                                               0.3/22.9 MB 8.9 MB/s eta 0:00:03
#                                               0.5/22.9 MB 5.6 MB/s eta 0:00:04
#      -                                        0.8/22.9 MB 5.7 MB/s eta 0:00:04
#      -                                        1.1/22.9 MB 6.3 MB/s eta 0:00:04
#      --                                       1.4/22.9 MB 5.9 MB/s eta 0:00:04
# ...

# %%
pip install --upgrade attrs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install leafmap
# Out:
# ...
#                                               0.0/1.8 MB ? eta -:--:--
#      ------                                   0.3/1.8 MB 8.6 MB/s eta 0:00:01
#      --------------                           0.7/1.8 MB 8.3 MB/s eta 0:00:01
#      ---------------------                    1.0/1.8 MB 7.6 MB/s eta 0:00:01
#      -----------------------------            1.3/1.8 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------        1.5/1.8 MB 7.5 MB/s eta 0:00:01
#      ---------------------------------------  1.8/1.8 MB 7.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.8/1.8 MB 6.8 MB/s eta 0:00:00
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      -----------                              0.4/1.2 MB 11.2 MB/s eta 0:00:01
#      -------------------                      0.6/1.2 MB 7.5 MB/s eta 0:00:01
#      ------------------------------           0.9/1.2 MB 7.4 MB/s eta 0:00:01
# ...
